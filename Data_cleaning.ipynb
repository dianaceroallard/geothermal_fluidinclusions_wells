# %% [markdown]
# # Data Cleaning
#
# Data files:

# %%
raw = './data/raw_collated.csv'

# %% [markdown]
# Imports:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Cleaning data

# %%
df = pd.read_csv(raw, index_col=0)
# Out:
# /home/geodev/anaconda3/envs/geothack/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (6,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#                   Type Geothermal Province       State Field Well ID  \
# 0  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 1  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 2  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 3  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 4  Transform Extension       Sierra Nevada  California  COSO  15A-17
#
#   Sample ID Depth (ft) AMU1      AMU2    AMU3  ...  AMU176.UNKN  AMU177.UNKN  \
# 0      2202        510    0  294200.0   53.30  ...          0.0         0.00
# 1      2203        530    0  320600.0   48.95  ...          0.0        80.84
# 2      2204        550    0  385400.0  159.40  ...        592.6         0.00
# 3      2205        570    0  448600.0  122.90  ...        376.7         0.00
# 4      2206        590    0  293800.0   47.05  ...        241.1        33.28
#
#    AMU178.UNKN  AMU179.UNKN  AMU180.UNKN  FIT Well  Unnamed: 188  Unnamed: 8  \
# ...

# %%
df.shape
# Out:
# (9712, 192)

# %%
# yields ValueError: ValueError: could not convert string to float: 'STD'
#df['Depth (ft)'].astype('float64')

# %%
df['Depth (ft)'].str.contains('STD', na=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# Name: Depth (ft), Length: 9712, dtype: bool

# %%
df[df['Depth (ft)'].str.contains('STD', na=False)]
# Out:
#                     Type Geothermal Province       State Field Well ID  \
# 218  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 99   Transform Extension       Sierra Nevada  California  COSO  23A-17
# 319  Transform Extension       Sierra Nevada  California  COSO  23A-17
# 354  Transform Extension       Sierra Nevada  California  COSO  23A-17
# 355  Transform Extension       Sierra Nevada  California  COSO  23A-17
# 356  Transform Extension       Sierra Nevada  California  COSO  23A-17
# 357  Transform Extension       Sierra Nevada  California  COSO  23A-17
# 358  Transform Extension       Sierra Nevada  California  COSO  23A-17
# 359  Transform Extension       Sierra Nevada  California  COSO  23A-17
# 360  Transform Extension       Sierra Nevada  California  COSO  23A-17
# 361  Transform Extension       Sierra Nevada  California  COSO  23A-17
# 362  Transform Extension       Sierra Nevada  California  COSO  23A-17
# ...

# %%
df[df['Depth (ft)'].str.contains('-', na=False)]
# Out:
#                     Type Geothermal Province       State Field Well ID  \
# 418  Transform Extension       Sierra Nevada  California  COSO     337
# 419  Transform Extension       Sierra Nevada  California  COSO     337
# 420  Transform Extension       Sierra Nevada  California  COSO     337
# 421  Transform Extension       Sierra Nevada  California  COSO     337
# 422  Transform Extension       Sierra Nevada  California  COSO     337
# ..                   ...                 ...         ...   ...     ...
# 499  Transform Extension       Sierra Nevada  California  COSO     337
# 500  Transform Extension       Sierra Nevada  California  COSO     337
# 501  Transform Extension       Sierra Nevada  California  COSO     337
# 502  Transform Extension       Sierra Nevada  California  COSO     337
# 503  Transform Extension       Sierra Nevada  California  COSO     337
#
#     Sample ID Depth (ft) AMU1       AMU2     AMU3  ...  AMU176.UNKN  \
# ...

# %%
df.loc[df['Depth (ft)'].str.contains('-', na=False), 'Depth (ft)'] = np.nan
df.loc[df['Depth (ft)'].str.contains('STD', na=False), 'Depth (ft)'] = np.nan

# %%
df['Depth (ft)'] = df['Depth (ft)'].astype('float64')

# %%
df['Depth (ft)'].dtypes
# Out:
# dtype('float64')

# %%
#df['Sample ID'].astype('float64')

# %%
df.loc[df['Sample ID'].str.contains('-', na=False), 'Sample ID'] = np.nan

# %%
df['Sample ID'] = df['Sample ID'].astype('float64')

# %%
# yields ValueError: could not convert string to float: '836.0 0.0000E+00'
#df.iloc[:, 7].astype('float64')

# %%
df.columns[7]
# Out:
# 'AMU1'

# %%
df.loc[df['AMU1'].str.contains('E+', regex=False, na=False) == True]
# Out:
#                     Type Geothermal Province       State Field Well ID  \
# 0    Transform Extension       Sierra Nevada  California  COSO   24A-8
# 1    Transform Extension       Sierra Nevada  California  COSO   24A-8
# 2    Transform Extension       Sierra Nevada  California  COSO   24A-8
# 3    Transform Extension       Sierra Nevada  California  COSO   24A-8
# 4    Transform Extension       Sierra Nevada  California  COSO   24A-8
# ..                   ...                 ...         ...   ...     ...
# 308  Transform Extension       Sierra Nevada  California  COSO   24A-8
# 309  Transform Extension       Sierra Nevada  California  COSO   24A-8
# 310  Transform Extension       Sierra Nevada  California  COSO   24A-8
# 311  Transform Extension       Sierra Nevada  California  COSO   24A-8
# 312  Transform Extension       Sierra Nevada  California  COSO   24A-8
#
#      Sample ID  Depth (ft)               AMU1      AMU2    AMU3  ...  \
# ...

# %%
#df[df['Well ID'] == '24A-8'][-50:]

# %%
df.loc[(df['AMU1'].str.contains('E+', regex=False, na=False) == True) &
       (df['Well ID'] == '24A-8'), 'AMU1'] = np.nan

# %%
df.loc[df['Well ID'] == '24A-8', 'AMU1'] = np.nan

# %%
df.loc[df['Well ID'] == '24A-8', 'AMU1'].astype('float64')
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 315   NaN
# 316   NaN
# 317   NaN
# 318   NaN
# 319   NaN
# Name: AMU1, Length: 320, dtype: float64

# %%
df.to_csv('./data/cleaned_types.csv', index=False)

# %%
df = pd.read_csv('./data/cleaned_types.csv')

# %%
df.head()
# Out:
#                   Type Geothermal Province       State Field Well ID  \
# 0  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 1  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 2  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 3  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 4  Transform Extension       Sierra Nevada  California  COSO  15A-17
#
#    Sample ID  Depth (ft)  AMU1      AMU2    AMU3  ...  AMU176.UNKN  \
# 0     2202.0       510.0   0.0  294200.0   53.30  ...          0.0
# 1     2203.0       530.0   0.0  320600.0   48.95  ...          0.0
# 2     2204.0       550.0   0.0  385400.0  159.40  ...        592.6
# 3     2205.0       570.0   0.0  448600.0  122.90  ...        376.7
# 4     2206.0       590.0   0.0  293800.0   47.05  ...        241.1
#
#    AMU177.UNKN  AMU178.UNKN  AMU179.UNKN  AMU180.UNKN  FIT Well  Unnamed: 188  \
# ...

# %%
df.shape
# Out:
# (9712, 192)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Columns: 192 entries, Type to Unnamed: 187
# dtypes: float64(186), object(6)
# memory usage: 14.2+ MB

# %%
for col in df.columns:
    if df[col].dtype != 'float64':
        print(col, df[col].dtype)
# Out:
# Type object
# Geothermal Province object
# State object
# Field object
# Well ID object
# FIT Well object

# %%
df.head()
# Out:
#                   Type Geothermal Province       State Field Well ID  \
# 0  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 1  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 2  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 3  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 4  Transform Extension       Sierra Nevada  California  COSO  15A-17
#
#    Sample ID  Depth (ft)  AMU1      AMU2    AMU3  ...  AMU176.UNKN  \
# 0     2202.0       510.0   0.0  294200.0   53.30  ...          0.0
# 1     2203.0       530.0   0.0  320600.0   48.95  ...          0.0
# 2     2204.0       550.0   0.0  385400.0  159.40  ...        592.6
# 3     2205.0       570.0   0.0  448600.0  122.90  ...        376.7
# 4     2206.0       590.0   0.0  293800.0   47.05  ...        241.1
#
#    AMU177.UNKN  AMU178.UNKN  AMU179.UNKN  AMU180.UNKN  FIT Well  Unnamed: 188  \
# ...
