# %% [markdown]
# ## 29 wells from Coso Field. Storaged in S3 bucket

# %%
import pandas as pd

# %% [markdown]
# #### Here an example for well 15A-17

# %%
well15A = pd.read_excel('s3://geotermaldata/S3FluidInclusionGasAnalysisData/COSO Field/15A-17-DOE-GDR.xls', skiprows =4)

# %%
well15A.head(10)
# Out:
#                   Type Geothermal Province       State Field Well ID  \
# 0  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 1  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 2  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 3  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 4  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 5  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 6  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 7  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 8  Transform Extension       Sierra Nevada  California  COSO  15A-17
# 9  Transform Extension       Sierra Nevada  California  COSO  15A-17
#
#    Sample ID Depth (ft)  AMU1    AMU2    AMU3  ...  AMU171.UNKN  AMU172.UNKN  \
# 0       2202        510     0  294200   53.30  ...       41.940            0
# ...

# %%
well15A.describe()
# Out:
#          Sample ID   AMU1          AMU2        AMU3          AMU4   AMU5  \
# count   339.000000  339.0  3.390000e+02  339.000000  3.390000e+02  339.0
# mean   2371.000000    0.0  4.365389e+05   70.990071  5.743606e+01    0.0
# std      98.005102    0.0  1.385959e+05   47.571286  7.916333e+01    0.0
# min    2202.000000    0.0  2.372000e+05    6.060000  0.000000e+00    0.0
# 25%    2286.500000    0.0  3.377000e+05   36.800000  5.371000e-12    0.0
# 50%    2371.000000    0.0  3.974000e+05   55.760000  3.077000e+01    0.0
# 75%    2455.500000    0.0  5.065500e+05   94.210000  7.261000e+01    0.0
# max    2540.000000    0.0  1.123000e+06  265.400000  3.851000e+02    0.0
#
#         AMU6   AMU7   AMU8   AMU9  ...   AMU171.UNKN  AMU172.UNKN  \
# count  339.0  339.0  339.0  339.0  ...  3.390000e+02        339.0
# mean     0.0    0.0    0.0    0.0  ...  3.586068e+00          0.0
# std      0.0    0.0    0.0    0.0  ...  1.144333e+01          0.0
# ...
